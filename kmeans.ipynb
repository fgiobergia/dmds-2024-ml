# %%
import matplotlib.pyplot as plt

import numpy as np

C = np.array([
    [4,0.5],
    [6, -0.5],
    [6, 1.5]
])

X1 = C[0] + np.random.normal(0, 0.5, size=(100,2))
X2 = C[1] + np.random.normal(0, 0.5, size=(1000,2))
X3 = C[2] + np.random.normal(0, 0.5, size=(1000,2))

# %%
X = np.vstack([X1, X2, X3])

# %%
plt.scatter(X[:,0], X[:,1], alpha=.5)

# %%
from sklearn.cluster import KMeans

km = KMeans(3, random_state=43, max_iter=1, n_init=1, init='random')
plt.scatter(X[:,0], X[:,1], c=y)
plt.figure()
km = KMeans(3, random_state=43, max_iter=2, n_init=1, init='random')
plt.scatter(X[:,0], X[:,1], c=y)
plt.figure()
km = KMeans(3, random_state=43, max_iter=3, n_init=1, init='random')
plt.scatter(X[:,0], X[:,1], c=y)
y = km.fit_predict(X)
