# %%
import numpy as np

# %%
x = np.random.normal(0, 1, size=(100000,))

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x, bins=100);

# %%
mask = (x > -3) & (x < 3)

# %%
x[mask].shape
# Out:
# (99728,)
